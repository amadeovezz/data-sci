# %%
from vision import img_cli
from importlib import reload
reload(img_cli)


img = img_cli.ImgCli("../images/crocodile-1.jpg", display_size=(679,430))
img.show()
# Out:
# <PIL.Image.Image image mode=L size=679x430>

# %%
img.gradient_image()
# Out:
# <PIL.Image.Image image mode=L size=679x430>

# %%
img.smooth(method='gaussian', size=3)
img.gradient_image()
# Out:
# <PIL.Image.Image image mode=L size=679x430>
